# %% [markdown]
# <h2 style='color:blue' align='center'>Celebrity Image Classification<h2>

# %% [markdown]
# This is a exercise project found from Codebasics youtube channel.

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/Einstein_JSTOR_Daily.jpg')
img.shape
# Out:
# (700, 1050, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (700, 1050)

# %%
gray
# Out:
# array([[107, 110, 112, ...,  43,  44,  41],
#        [106, 109, 111, ...,  44,  44,  41],
#        [103, 105, 108, ...,  43,  41,  38],
#        ...,
#        [134, 132, 130, ...,  52,  50,  50],
#        [131, 129, 127, ...,  51,  49,  49],
#        [129, 128, 125, ...,  50,  49,  49]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[180, 134, 473, 473]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (180, 134, 473, 473)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (473, 473, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        return
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Einstein_JSTOR_Daily.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Einstein_JSTOR_Daily.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/About Albert Einstein - Biography.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/About Albert Einstein - Biography.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/roger_penrose',
#  './dataset/cropped',
#  './dataset/apj_abdul_kalam',
#  './dataset/einstein']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/roger_penrose
# Generating cropped images in folder:  ./dataset/cropped/apj_abdul_kalam
# Generating cropped images in folder:  ./dataset/cropped/einstein

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'roger_penrose': ['./dataset/cropped/roger_penrose/roger_penrose26.png',
#   './dataset/cropped/roger_penrose/roger_penrose11.png',
#   './dataset/cropped/roger_penrose/roger_penrose12.png',
#   './dataset/cropped/roger_penrose/roger_penrose19.png',
#   './dataset/cropped/roger_penrose/roger_penrose23.png',
#   './dataset/cropped/roger_penrose/roger_penrose14.png',
#   './dataset/cropped/roger_penrose/roger_penrose20.png',
#   './dataset/cropped/roger_penrose/roger_penrose33.png',
#   './dataset/cropped/roger_penrose/roger_penrose3.png',
#   './dataset/cropped/roger_penrose/roger_penrose34.png',
#   './dataset/cropped/roger_penrose/roger_penrose6.png',
#   './dataset/cropped/roger_penrose/roger_penrose5.png',
#   './dataset/cropped/roger_penrose/roger_penrose15.png',
#   './dataset/cropped/roger_penrose/roger_penrose7.png',
#   './dataset/cropped/roger_penrose/roger_penrose2.png',
#   './dataset/cropped/roger_penrose/roger_penrose13.png',
#   './dataset/cropped/roger_penrose/roger_penrose18.png',
#   './dataset/cropped/roger_penrose/roger_penrose9.png',
#   './dataset/cropped/roger_penrose/roger_penrose35.png',
#   './dataset/cropped/roger_penrose/roger_penrose21.png',
#   './dataset/cropped/roger_penrose/roger_penrose17.png',
#   './dataset/cropped/roger_penrose/roger_penrose29.png',
#   './dataset/cropped/roger_penrose/roger_penrose31.png',
#   './dataset/cropped/roger_penrose/roger_penrose1.png',
#   './dataset/cropped/roger_penrose/roger_penrose30.png',
#   './dataset/cropped/roger_penrose/roger_penrose25.png',
#   './dataset/cropped/roger_penrose/roger_penrose32.png',
#   './dataset/cropped/roger_penrose/roger_penrose24.png',
#   './dataset/cropped/roger_penrose/roger_penrose27.png',
#   './dataset/cropped/roger_penrose/roger_penrose28.png'],
#  'apj_abdul_kalam': ['./dataset/cropped/apj_abdul_kalam/apj_abdul_kalam23.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam28.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam16.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam18.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam7.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam6.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam10.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam27.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam14.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam21.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam26.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam5.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam22.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam3.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam8.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam24.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam25.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam15.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam12.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam19.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam4.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam13.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam20.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam9.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam2.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam17.png',
#   './dataset/cropped/apj_abdul_kalam/apj_abdul_kalam11.png'],
#  'einstein': ['./dataset/cropped/einstein/einstein46.png',
#   './dataset/cropped/einstein/einstein13.png',
#   './dataset/cropped/einstein/einstein18.png',
#   './dataset/cropped/einstein/einstein51.png',
#   './dataset/cropped/einstein/einstein20.png',
#   './dataset/cropped/einstein/einstein26.png',
#   './dataset/cropped/einstein/einstein38.png',
#   './dataset/cropped/einstein/einstein47.png',
#   './dataset/cropped/einstein/einstein40.png',
#   './dataset/cropped/einstein/einstein15.png',
#   './dataset/cropped/einstein/einstein11.png',
#   './dataset/cropped/einstein/einstein44.png',
#   './dataset/cropped/einstein/einstein8.png',
#   './dataset/cropped/einstein/einstein41.png',
#   './dataset/cropped/einstein/einstein3.png',
#   './dataset/cropped/einstein/einstein57.png',
#   './dataset/cropped/einstein/einstein16.png',
#   './dataset/cropped/einstein/einstein49.png',
#   './dataset/cropped/einstein/einstein56.png',
#   './dataset/cropped/einstein/einstein10.png',
#   './dataset/cropped/einstein/einstein48.png',
#   './dataset/cropped/einstein/einstein42.png',
#   './dataset/cropped/einstein/einstein5.png',
#   './dataset/cropped/einstein/einstein22.png',
#   './dataset/cropped/einstein/einstein29.png',
#   './dataset/cropped/einstein/einstein31.png',
#   './dataset/cropped/einstein/einstein45.png',
#   './dataset/cropped/einstein/einstein28.png',
#   './dataset/cropped/einstein/einstein53.png',
#   './dataset/cropped/einstein/einstein30.png',
#   './dataset/cropped/einstein/einstein39.png',
#   './dataset/cropped/einstein/einstein21.png',
#   './dataset/cropped/einstein/einstein54.png',
#   './dataset/cropped/einstein/einstein52.png',
#   './dataset/cropped/einstein/einstein58.png',
#   './dataset/cropped/einstein/einstein27.png',
#   './dataset/cropped/einstein/einstein2.png',
#   './dataset/cropped/einstein/einstein62.png',
#   './dataset/cropped/einstein/einstein19.png',
#   './dataset/cropped/einstein/einstein24.png',
#   './dataset/cropped/einstein/einstein17.png',
#   './dataset/cropped/einstein/einstein61.png',
#   './dataset/cropped/einstein/einstein23.png',
#   './dataset/cropped/einstein/einstein60.png',
#   './dataset/cropped/einstein/einstein14.png',
#   './dataset/cropped/einstein/einstein7.png',
#   './dataset/cropped/einstein/einstein4.png',
#   './dataset/cropped/einstein/einstein43.png',
#   './dataset/cropped/einstein/einstein33.png',
#   './dataset/cropped/einstein/einstein35.png',
#   './dataset/cropped/einstein/einstein12.png',
#   './dataset/cropped/einstein/einstein37.png',
#   './dataset/cropped/einstein/einstein32.png',
#   './dataset/cropped/einstein/einstein25.png',
#   './dataset/cropped/einstein/einstein34.png',
#   './dataset/cropped/einstein/einstein50.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'roger_penrose': 0, 'apj_abdul_kalam': 1, 'einstein': 2}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[129],
#        [144],
#        [146],
#        ...,
#        [245],
#        [ 63],
#        [191]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (113, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.896551724137931

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.40      0.57         5
#            2       0.82      1.00      0.90        14
#
#     accuracy                           0.90        29
#    macro avg       0.94      0.80      0.82        29
# weighted avg       0.91      0.90      0.88        29

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.844853
# 1        random_forest    0.691176
# 2  logistic_regression    0.844118
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9310344827586207

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7931034482758621

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.896551724137931

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[10,  0,  0],
#        [ 0,  4,  1],
#        [ 1,  0, 13]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'roger_penrose': 0, 'apj_abdul_kalam': 1, 'einstein': 2}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# /home/cosmic/anaconda3/lib/python3.8/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /home/cosmic/anaconda3/lib/python3.8/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: joblib in /home/cosmic/anaconda3/lib/python3.8/site-packages (0.17.0)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
